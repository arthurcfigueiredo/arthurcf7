# %% [markdown]
# ## PHYTON PARA CIÊNCIA DE DADOS
#
# INSTITUTO FEDERAL DE MINAS GERAIS - CAMPUS OURO PRETO
#
# INTELIGÊNCIA ARTIFICIAL
#
# ARTHUR CARDOSO FIGUEIREDO

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# CARREGAMENTO DOS DADOS

# %%
pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
heartdata = pd.read_csv('C:\dataset_heart.csv')

# %%
heartdata
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral
# 0     70     1                4                     130                322  \
# 1     67     0                3                     115                564
# 2     57     1                2                     124                261
# 3     64     1                4                     128                263
# 4     74     0                2                     120                269
# ..   ...   ...              ...                     ...                ...
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results
# ...

# %% [markdown]
# Vendo algumas informações com .info() e .describe()

# %%
heartdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   270 non-null    int64
#  1   sex                                   270 non-null    int64
#  2   chest pain type                       270 non-null    int64
#  3   resting blood pressure                270 non-null    int64
#  4   serum cholestoral                     270 non-null    int64
#  5   fasting blood sugar                   270 non-null    int64
#  6   resting electrocardiographic results  270 non-null    int64
#  7   max heart rate                        270 non-null    int64
#  8   exercise induced angina               270 non-null    int64
#  9   oldpeak                               270 non-null    float64
#  10  ST segment                            270 non-null    int64
# ...

# %%
heartdata.describe()
# Out:
#               age        sex   chest pain type  resting blood pressure
# count  270.000000  270.000000       270.000000              270.000000  \
# mean    54.433333    0.677778         3.174074              131.344444
# std      9.109067    0.468195         0.950090               17.861608
# min     29.000000    0.000000         1.000000               94.000000
# 25%     48.000000    0.000000         3.000000              120.000000
# 50%     55.000000    1.000000         3.000000              130.000000
# 75%     61.000000    1.000000         4.000000              140.000000
# max     77.000000    1.000000         4.000000              200.000000
#
#        serum cholestoral  fasting blood sugar
# count         270.000000           270.000000  \
# mean          249.659259             0.148148
# std            51.686237             0.355906
# min           126.000000             0.000000
# 25%           213.000000             0.000000
# ...

# %%
diabetsdata = pd.read_csv('C:\diabetes_prediction_dataset.csv')

# %%
diabetsdata
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi
# 0      Female  80.0             0              1           never  25.19  \
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
diabetsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
diabetsdata.describe()
# Out:
#                  age  hypertension  heart_disease            bmi
# count  100000.000000  100000.00000  100000.000000  100000.000000  \
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# Fusão das bases de dados

# %%
merged_df = pd.merge(heartdata,diabetsdata,left_on='serum cholestoral',right_on='blood_glucose_level')

# %%
merged_df
# Out:
#        age_x  sex   chest pain type  resting blood pressure
# 0         50     1                4                     144  \
# 1         50     1                4                     144
# 2         50     1                4                     144
# 3         50     1                4                     144
# 4         50     1                4                     144
# ...      ...   ...              ...                     ...
# 27464     44     1                2                     120
# 27465     44     1                2                     120
# 27466     44     1                2                     120
# 27467     44     1                2                     120
# 27468     44     1                2                     120
#
#        serum cholestoral  fasting blood sugar
# 0                    200                    0  \
# 1                    200                    0
# 2                    200                    0
# 3                    200                    0
# ...

# %%
merged_df.columns
# Out:
# Index(['age_x', 'sex ', 'chest pain type', 'resting blood pressure',
#        'serum cholestoral', 'fasting blood sugar',
#        'resting electrocardiographic results', 'max heart rate',
#        'exercise induced angina', 'oldpeak', 'ST segment', 'major vessels',
#        'thal', 'heart disease', 'gender', 'age_y', 'hypertension',
#        'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level',
#        'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %% [markdown]
# nan_proportion = merged_df.isna().mean()
# nan_proportion

# %% [markdown]
# Análise Exploratória dos Dados

# %%
nan_proportion = merged_df.isna().mean()
nan_proportion
# Out:
# age_x                                   0.0
# sex                                     0.0
# chest pain type                         0.0
# resting blood pressure                  0.0
# serum cholestoral                       0.0
# fasting blood sugar                     0.0
# resting electrocardiographic results    0.0
# max heart rate                          0.0
# exercise induced angina                 0.0
# oldpeak                                 0.0
# ST segment                              0.0
# major vessels                           0.0
# thal                                    0.0
# heart disease                           0.0
# gender                                  0.0
# age_y                                   0.0
# hypertension                            0.0
# heart_disease                           0.0
# smoking_history                         0.0
# bmi                                     0.0
# HbA1c_level                             0.0
# ...

# %% [markdown]
# Observação:Podemos observar que não há valores faltantes nos nossos analisados.

# %%
average_age = merged_df['age_x'].mean()
min_age = merged_df['age_x'].min()
max_age = merged_df['age_x'].max()

# %%
print(f'{min_age}, {average_age}, {max_age}')
# Out:
# 42, 50.993774800684406, 61

# %% [markdown]
# Percebemos pela análise acima, que a idade mínima dos dados de homens coletados é de 42 anos , a idade média de 50 e a máxima idade é de 61 anos

# %%
import matplotlib.pyplot as plt

plt.hist(merged_df['age_x'])
# Out:
# (array([ 636., 8950.,    0.,    0., 7600.,    0.,    0., 7702., 1310.,
#         1271.]),
#  array([42. , 43.9, 45.8, 47.7, 49.6, 51.5, 53.4, 55.3, 57.2, 59.1, 61. ]),
#  <BarContainer object of 10 artists>)

# %%
merged_df['age_x'] = merged_df['age_x'].fillna(200)
nan_proportion = merged_df.isna().mean()
nan_proportion
# Out:
# age_x                                   0.0
# sex                                     0.0
# chest pain type                         0.0
# resting blood pressure                  0.0
# serum cholestoral                       0.0
# fasting blood sugar                     0.0
# resting electrocardiographic results    0.0
# max heart rate                          0.0
# exercise induced angina                 0.0
# oldpeak                                 0.0
# ST segment                              0.0
# major vessels                           0.0
# thal                                    0.0
# heart disease                           0.0
# gender                                  0.0
# age_y                                   0.0
# hypertension                            0.0
# heart_disease                           0.0
# smoking_history                         0.0
# bmi                                     0.0
# HbA1c_level                             0.0
# ...

# %%
merged_df.dtypes
# Out:
# age_x                                     int64
# sex                                       int64
# chest pain type                           int64
# resting blood pressure                    int64
# serum cholestoral                         int64
# fasting blood sugar                       int64
# resting electrocardiographic results      int64
# max heart rate                            int64
# exercise induced angina                   int64
# oldpeak                                 float64
# ST segment                                int64
# major vessels                             int64
# thal                                      int64
# heart disease                             int64
# gender                                   object
# age_y                                   float64
# hypertension                              int64
# heart_disease                             int64
# smoking_history                          object
# bmi                                     float64
# ...

# %%
average_age = merged_df['resting blood pressure'].mean()
min_age = merged_df['resting blood pressure'].min()
max_age = merged_df['resting blood pressure'].max()

# %%
print(f'{min_age}, {average_age}, {max_age}')
# Out:
# 105, 133.16025337653355, 150

# %%
import matplotlib.pyplot as plt

plt.hist(merged_df['resting blood pressure'])
# Out:
# (array([ 636., 7712.,  635., 1874.,  674.,    0.,    0.,    0., 7600.,
#         8338.]),
#  array([105. , 109.5, 114. , 118.5, 123. , 127.5, 132. , 136.5, 141. ,
#         145.5, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
merged_df['resting blood pressure'] = merged_df['resting blood pressure'].fillna(average_age)
nan_proportion = merged_df.isna().mean()
nan_proportion
# Out:
# age_x                                   0.0
# sex                                     0.0
# chest pain type                         0.0
# resting blood pressure                  0.0
# serum cholestoral                       0.0
# fasting blood sugar                     0.0
# resting electrocardiographic results    0.0
# max heart rate                          0.0
# exercise induced angina                 0.0
# oldpeak                                 0.0
# ST segment                              0.0
# major vessels                           0.0
# thal                                    0.0
# heart disease                           0.0
# gender                                  0.0
# age_y                                   0.0
# hypertension                            0.0
# heart_disease                           0.0
# smoking_history                         0.0
# bmi                                     0.0
# HbA1c_level                             0.0
# ...

# %%
merged_df.dtypes
# Out:
# age_x                                     int64
# sex                                       int64
# chest pain type                           int64
# resting blood pressure                    int64
# serum cholestoral                         int64
# fasting blood sugar                       int64
# resting electrocardiographic results      int64
# max heart rate                            int64
# exercise induced angina                   int64
# oldpeak                                 float64
# ST segment                                int64
# major vessels                             int64
# thal                                      int64
# heart disease                             int64
# gender                                   object
# age_y                                   float64
# hypertension                              int64
# heart_disease                             int64
# smoking_history                          object
# bmi                                     float64
# ...

# %%
embarked_encoded = pd.get_dummies(merged_df['age_x'], prefix='age_x')
#merged_df.drop('age_x',axis=1)
merged_df = pd.concat([merged_df,embarked_encoded],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

le = LabelEncoder()

# %%
for col in merged_df.columns:
    if merged_df[col].dtype == 'object':
        merged_df[col] = le.fit_transform(merged_df[col].astype(str))

# %%
merged_df
# Out:
#        age_x  sex   chest pain type  resting blood pressure
# 0         50     1                4                     144  \
# 1         50     1                4                     144
# 2         50     1                4                     144
# 3         50     1                4                     144
# 4         50     1                4                     144
# ...      ...   ...              ...                     ...
# 27464     44     1                2                     120
# 27465     44     1                2                     120
# 27466     44     1                2                     120
# 27467     44     1                2                     120
# 27468     44     1                2                     120
#
#        serum cholestoral  fasting blood sugar
# 0                    200                    0  \
# 1                    200                    0
# 2                    200                    0
# 3                    200                    0
# ...

# %%
merged_df.columns
# Out:
# Index(['age_x', 'sex ', 'chest pain type', 'resting blood pressure',
#        'serum cholestoral', 'fasting blood sugar',
#        'resting electrocardiographic results', 'max heart rate',
#        'exercise induced angina', 'oldpeak', 'ST segment', 'major vessels',
#        'thal', 'heart disease', 'gender', 'age_y', 'hypertension',
#        'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level',
#        'blood_glucose_level', 'diabetes', 'age_x_42', 'age_x_44', 'age_x_45',
#        'age_x_50', 'age_x_57', 'age_x_58', 'age_x_60', 'age_x_61'],
#       dtype='object')

# %%
columns_to_plot1 = ['age_x', 'sex ', 'chest pain type', 'resting blood pressure',
       'serum cholestoral']
columns_to_plot2 = ['age_x','smoking_history', 'hypertension', 'diabetes','heart_disease']

# %%
import seaborn as sns

# %%
sns.pairplot(merged_df[columns_to_plot1],hue='age_x' )

# %%
sns.pairplot(merged_df[columns_to_plot2],hue='age_x')

# %%
sns.pairplot(merged_df[columns_to_plot2],hue='age_x')

# %%
sns.pairplot(merged_df[columns_to_plot2],hue='age_x')

# %%
sns.pairplot(merged_df[['resting blood pressure','diabetes']],hue=''

# %%
sns.pairplot(merged_df[['max heart rate','resting blood pressure	serum ']],hue='age_x')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 sns.pairplot(merged_df[['max heart rate','resting blood pressure	serum ']],hue='age_x')
#
# File c:\Users\laop_\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\laop_\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
# ...
