# %% [markdown]
# ## PHYTON PARA CIÊNCIA DE DADOS
#
# INSTITUTO FEDERAL DE MINAS GERAIS - CAMPUS OURO PRETO
#
# INTELIGÊNCIA ARTIFICIAL
#
#  ARTHUR CARDOSO FIGUEIREDO
#
#
# PROF. DR. RODRIGO CÉSAR PEDROSA SILVA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# CARREGAMENTO DOS DADOS

# %%
pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# DatSet 1 : GDP per capita all countries

# %%
GDP = pd.read_csv('C:\GDP.csv')

# %%
GDP
# Out:
#          Country  Country Code          1990          1991          1992
# 0           Aruba          ABW  24101.109430  25870.755940  26533.343900  \
# 1     Afghanistan          AFG           NaN           NaN           NaN
# 2          Angola          AGO   3089.683369   3120.356148   2908.160798
# 3         Albania          ALB   2549.473022   1909.114038   1823.307673
# 4      Arab World          ARB   6808.206995   6872.273195   7255.328362
# ..            ...          ...           ...           ...           ...
# 255        Kosovo          XKX           NaN           NaN           NaN
# 256   Yemen, Rep.          YEM   2223.028771   2325.263661   2443.920401
# 257  South Africa          ZAF   6424.502215   6414.057923   6261.716184
# 258        Zambia          ZMB   1517.926292   1528.781247   1499.340446
# 259      Zimbabwe          ZWE   1829.677575   1949.732966   1777.843425
#
#              1993          1994          1995          1996          1997
# ...

# %% [markdown]
# O PIB com base na Paridade do Poder de Compra (PPC) é uma medida mais útil do que o PIB nominal para avaliar o mercado interno de um país. Ele leva em conta o custo relativo dos bens locais, serviços e taxas de inflação, evitando distorções causadas pelas taxas de câmbio internacionais. Em suma, o PIB com base na PPC fornece uma visão mais precisa das condições econômicas e do poder de compra dentro de um país, o dat set possui todos os países e os PIB, de 1990 a 2019.

# %% [markdown]
# Vendo algumas informações com .info() e .describe()

# %%
GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       260 non-null    object
#  1   Country Code  260 non-null    object
#  2   1990          209 non-null    float64
#  3   1991          211 non-null    float64
#  4   1992          213 non-null    float64
#  5   1993          215 non-null    float64
#  6   1994          218 non-null    float64
#  7   1995          224 non-null    float64
#  8   1996          224 non-null    float64
#  9   1997          225 non-null    float64
#  10  1998          226 non-null    float64
#  11  1999          227 non-null    float64
#  12  2000          236 non-null    float64
#  13  2001          237 non-null    float64
#  14  2002          238 non-null    float64
#  15  2003          238 non-null    float64
#  16  2004          238 non-null    float64
# ...

# %% [markdown]
# O DataFrame possui 260 entradas (linhas) e 32 colunas.
# A maioria das colunas contém dados numéricos do tipo float64, representando valores para cada ano de 1990 a 2019.
# Algumas colunas possuem valores ausentes, indicados pelo count "Non-Null Count" menor que o número total de entradas (260).
# Observação: A última coluna "2019" possui todos os valores ausentes, conforme indicado pela contagem "Non-Null Count" de zero.

# %% [markdown]
# A contagem (count) indica o número de valores não nulos em cada coluna.
# A média (mean) representa a média dos valores em cada coluna.
# O desvio padrão (std) indica a dispersão dos valores em cada coluna.
# Além dessas informações, o método describe() também fornece o valor mínimo (min), quartis (25%, 50%, 75%), e o valor máximo (max) de cada coluna.

# %% [markdown]
# Dataset 2 Global Air Pollution Dataset

# %%
polui = pd.read_csv('C:\global air pollution dataset.csv')

# %%
polui
# Out:
#                         Country              City  AQI Value AQI Category
# 0            Russian Federation        Praskoveya         51     Moderate  \
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category
# ...

# %% [markdown]
# Este conjunto de dados contém informações geolocalizadas sobre poluentes atmosféricos, como Dióxido de Nitrogênio (NO2), Ozônio (O3), Monóxido de Carbono (CO) e Material Particulado (PM2.5). Os valores são fornecidos em termos de Índice de Qualidade do Ar (AQI) e são categorizados de acordo com a gravidade da poluição. O conjunto de dados inclui informações sobre diferentes países e cidades, fornecendo uma visão abrangente da poluição do ar global.
# País: Nome do país
# Cidade: Nome da cidade
# Valor AQI : Valor global do IQA da cidade
# Categoria AQI : Categoria AQI geral da cidade
# Valor CO AQI : Valor AQI do Monóxido de Carbono da cidade
# CO AQI Categoria : Categoria AQI de Monóxido de Carbono da cidade
# Valor AQI de ozônio : Valor AQI do Ozônio da cidade
# Ozônio AQI Categoria : AQI categoria de Ozônio da cidade
# NO2 AQI Valor : Valor AQI de Dióxido de Nitrogênio da cidade
# NO2 AQI Categoria : AQI categoria de Dióxido de Nitrogênio da cidade
# Valor PM2.5 AQI : Valor AQI de Material Particulado com diâmetro igual ou inferior a 2,5 micrômetros da cidade
# PM2.5 AQI Categoria : Categoria AQI de Material Particulado com diâmetro igual ou inferior a 2,5 micrômetros da cidade

# %% [markdown]
# Vendo algumas informações com .info() e .describe()

# %%
polui.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             23036 non-null  object
#  1   City                23462 non-null  object
#  2   AQI Value           23463 non-null  int64
#  3   AQI Category        23463 non-null  object
#  4   CO AQI Value        23463 non-null  int64
#  5   CO AQI Category     23463 non-null  object
#  6   Ozone AQI Value     23463 non-null  int64
#  7   Ozone AQI Category  23463 non-null  object
#  8   NO2 AQI Value       23463 non-null  int64
#  9   NO2 AQI Category    23463 non-null  object
#  10  PM2.5 AQI Value     23463 non-null  int64
#  11  PM2.5 AQI Category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# O DataFrame possui 23463 entradas e 12 colunas.
# A coluna "Country" possui 23036 valores não nulos, indicando 427 valores ausentes.
# A coluna "City" não possui valores ausentes.
# As colunas "AQI Value", "CO AQI Value", "Ozone AQI Value", "NO2 AQI Value" e "PM2.5 AQI Value" contêm valores inteiros.
# As colunas "AQI Category", "CO AQI Category", "Ozone AQI Category", "NO2 AQI Category" e "PM2.5 AQI Category" contêm valores categóricos.
# A coluna "AQI Value" possui um valor máximo de 23463.
# A coluna "CO AQI Value" possui um valor máximo de 23463.
# A coluna "Ozone AQI Value" possui um valor máximo de 23463.
# A coluna "NO2 AQI Value" possui um valor máximo de 23463.
# A coluna "PM2.5 AQI Value" possui um valor máximo de 23463.

# %%
polui.describe()
# Out:
#           AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value
# count  23463.000000  23463.000000     23463.000000   23463.000000  \
# mean      72.010868      1.368367        35.193709       3.063334
# std       56.055220      1.832064        28.098723       5.254108
# min        6.000000      0.000000         0.000000       0.000000
# 25%       39.000000      1.000000        21.000000       0.000000
# 50%       55.000000      1.000000        31.000000       1.000000
# 75%       79.000000      1.000000        40.000000       4.000000
# max      500.000000    133.000000       235.000000      91.000000
#
#        PM2.5 AQI Value
# count     23463.000000
# mean         68.519755
# std          54.796443
# min           0.000000
# 25%          35.000000
# 50%          54.000000
# 75%          79.000000
# max         500.000000

# %% [markdown]
# O número total de amostras é 23.463.
# O Índice de Qualidade do Ar (AQI Value) varia de 6 a 500, com uma média de 72.01.
# O Índice de Monóxido de Carbono (CO AQI Value) varia de 0 a 133, com uma média de 1.37.
# O Índice de Ozônio (Ozone AQI Value) varia de 0 a 235, com uma média de 35.19.
# O Índice de Dióxido de Nitrogênio (NO2 AQI Value) varia de 0 a 91, com uma média de 3.06.
# O Índice de Partículas Finas (PM2.5 AQI Value) varia de 0 a 500, com uma média de 68.52.
# Essas informações fornecem uma visão geral da distribuição e intensidade da poluição do ar nas localidades analisadas.

# %% [markdown]
# Fusão das bases de dados

# %%
GDP = GDP.rename(columns={'Country ': 'Country'})

# %% [markdown]
# O código merged_df = pd.merge(GDP, polui, left_on='Country', right_on='Country') realiza uma junção (merge) entre os DataFrames "GDP" e "polui" com base na coluna "Country". Ele cria um novo DataFrame chamado merged_df que combina as informações econômicas do Produto Interno Bruto (PIB) com os dados de qualidade do ar.
#
# A junção é feita utilizando a coluna "Country" como chave de correspondência, ou seja, os registros são combinados com base nos países em comum entre os dois conjuntos de dados.
#
# O DataFrame resultante, merged_df, contém as informações combinadas dos dois DataFrames, permitindo a análise conjunta das variáveis econômicas e de qualidade do ar para cada país. Isso possibilita investigar possíveis relações entre o PIB e a qualidade do ar, fornecendo insights sobre a influência da atividade econômica na poluição atmosférica.

# %%
merged_df = pd.merge(GDP, polui, left_on='Country', right_on='Country')

# %%
merged_df
# Out:
#            Country Country Code          1990          1991          1992
# 0            Aruba          ABW  24101.109430  25870.755940  26533.343900  \
# 1      Afghanistan          AFG           NaN           NaN           NaN
# 2      Afghanistan          AFG           NaN           NaN           NaN
# 3      Afghanistan          AFG           NaN           NaN           NaN
# 4      Afghanistan          AFG           NaN           NaN           NaN
# ...            ...          ...           ...           ...           ...
# 18571     Zimbabwe          ZWE   1829.677575   1949.732966   1777.843425
# 18572     Zimbabwe          ZWE   1829.677575   1949.732966   1777.843425
# 18573     Zimbabwe          ZWE   1829.677575   1949.732966   1777.843425
# 18574     Zimbabwe          ZWE   1829.677575   1949.732966   1777.843425
# 18575     Zimbabwe          ZWE   1829.677575   1949.732966   1777.843425
#
#              1993         1994          1995          1996          1997  ...
# ...

# %%
merged_df.columns
# Out:
# Index(['Country', 'Country Code', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', 'City',
#        'AQI Value', 'AQI Category', 'CO AQI Value', 'CO AQI Category',
#        'Ozone AQI Value', 'Ozone AQI Category', 'NO2 AQI Value',
#        'NO2 AQI Category', 'PM2.5 AQI Value', 'PM2.5 AQI Category'],
#       dtype='object')

# %%
colunas= ['Country', 'City',
       'AQI Value', 'AQI Category', 'CO AQI Value', 'CO AQI Category',
       'Ozone AQI Value', 'Ozone AQI Category', 'NO2 AQI Value',
       'NO2 AQI Category', 'PM2.5 AQI Value', 'PM2.5 AQI Category',  '2018',]
merged_df = merged_df[colunas]

# %%
merged_df
# Out:
#            Country            City  AQI Value                    AQI Category
# 0            Aruba      Oranjestad        163                       Unhealthy  \
# 1      Afghanistan        Kuhestan        151                       Unhealthy
# 2      Afghanistan          Qunduz        117  Unhealthy for Sensitive Groups
# 3      Afghanistan          Rostaq        113  Unhealthy for Sensitive Groups
# 4      Afghanistan          Tokzar         77                        Moderate
# ...            ...             ...        ...                             ...
# 18571     Zimbabwe      Zvishavane         39                            Good
# 18572     Zimbabwe    Mount Darwin         26                            Good
# 18573     Zimbabwe        Bulawayo         65                        Moderate
# 18574     Zimbabwe      Beitbridge         52                        Moderate
# 18575     Zimbabwe  Victoria Falls         26                            Good
#
# ...

# %% [markdown]
# O DataFrame resultante da junção, merged_df, contém informações sobre o Produto Interno Bruto (PIB) de diferentes países ao longo dos anos, juntamente com dados sobre a qualidade do ar em várias cidades. As colunas incluem o nome do país, o código do país, os valores do PIB para cada ano de 1990 a 2019, o nome da cidade e os valores do Índice de Qualidade do Ar (AQI) para diferentes poluentes, como monóxido de carbono (CO), ozônio, dióxido de nitrogênio (NO2) e material particulado 2.5 (PM2.5). Essas informações combinadas fornecem insights sobre a relação entre o crescimento econômico e a qualidade do ar em diferentes países e cidades.

# %% [markdown]
# # Análise Exploratória dos Dados

# %%
nan_proportion = merged_df.isna().mean()
nan_proportion
# Out:
# Country               0.000000
# City                  0.000054
# AQI Value             0.000000
# AQI Category          0.000000
# CO AQI Value          0.000000
# CO AQI Category       0.000000
# Ozone AQI Value       0.000000
# Ozone AQI Category    0.000000
# NO2 AQI Value         0.000000
# NO2 AQI Category      0.000000
# PM2.5 AQI Value       0.000000
# PM2.5 AQI Category    0.000000
# 2018                  0.002799
# dtype: float64

# %% [markdown]
# A variável nan_proportion contém a proporção de valores ausentes (NaN) em cada coluna do DataFrame merged_df. A análise revela que a coluna "Country" não possui valores ausentes, enquanto a coluna "City" apresenta uma pequena proporção de valores ausentes (aproximadamente 0,0054%). As demais colunas, que representam informações sobre a qualidade do ar e o PIB, não possuem valores ausentes. Apenas a coluna "2018" apresenta uma proporção de valores ausentes de aproximadamente 0,28%. Essas informações fornecem uma visão geral da presença de valores ausentes no conjunto de dados combinado.

# %%
merged_df= merged_df.dropna(subset=['2018'])

# %% [markdown]
# O comando merged_df.dropna(subset=['2018']) remove as linhas do DataFrame merged_df que possuem valores ausentes na coluna "2018". Após a execução do comando, o DataFrame é atualizado, mantendo apenas as linhas com valores válidos na coluna "2018". Isso permite trabalhar com um conjunto de dados completo em relação a essa coluna.

# %%
merged_df= merged_df.dropna(subset=['City'])

# %% [markdown]
# Da mesma maneira o comando merged_df.dropna(subset=['City']) remove as linhas com valores ausentes na coluna "City" do DataFrame merged_df, resultando em um novo DataFrame sem registros incompletos. Isso permite trabalhar apenas com as entradas que possuem informações válidas de cidade.

# %%
merged_df
# Out:
#            Country            City  AQI Value                    AQI Category
# 1      Afghanistan        Kuhestan        151                       Unhealthy  \
# 2      Afghanistan          Qunduz        117  Unhealthy for Sensitive Groups
# 3      Afghanistan          Rostaq        113  Unhealthy for Sensitive Groups
# 4      Afghanistan          Tokzar         77                        Moderate
# 5      Afghanistan         Carikar         67                        Moderate
# ...            ...             ...        ...                             ...
# 18571     Zimbabwe      Zvishavane         39                            Good
# 18572     Zimbabwe    Mount Darwin         26                            Good
# 18573     Zimbabwe        Bulawayo         65                        Moderate
# 18574     Zimbabwe      Beitbridge         52                        Moderate
# 18575     Zimbabwe  Victoria Falls         26                            Good
#
# ...

# %%
merged_df = merged_df.rename(columns={'2018': 'PIB_2018'})

# %% [markdown]
# O comando merged_df.rename(columns={'2018': 'PIB_2018'}) renomeia a coluna '2018' para 'PIB_2018' no DataFrame merged_df. Isso altera o nome da coluna para torná-lo mais descritivo ou adequado ao contexto dos dados.

# %%
merged_df
# Out:
#            Country            City  AQI Value                    AQI Category
# 1      Afghanistan        Kuhestan        151                       Unhealthy  \
# 2      Afghanistan          Qunduz        117  Unhealthy for Sensitive Groups
# 3      Afghanistan          Rostaq        113  Unhealthy for Sensitive Groups
# 4      Afghanistan          Tokzar         77                        Moderate
# 5      Afghanistan         Carikar         67                        Moderate
# ...            ...             ...        ...                             ...
# 18571     Zimbabwe      Zvishavane         39                            Good
# 18572     Zimbabwe    Mount Darwin         26                            Good
# 18573     Zimbabwe        Bulawayo         65                        Moderate
# 18574     Zimbabwe      Beitbridge         52                        Moderate
# 18575     Zimbabwe  Victoria Falls         26                            Good
#
# ...

# %%
nan_proportion = merged_df.isna().mean()
nan_proportion
# Out:
# Country               0.0
# City                  0.0
# AQI Value             0.0
# AQI Category          0.0
# CO AQI Value          0.0
# CO AQI Category       0.0
# Ozone AQI Value       0.0
# Ozone AQI Category    0.0
# NO2 AQI Value         0.0
# NO2 AQI Category      0.0
# PM2.5 AQI Value       0.0
# PM2.5 AQI Category    0.0
# PIB_2018              0.0
# dtype: float64

# %% [markdown]
# O comando merged_df.isna().mean() calcula a proporção de valores ausentes em cada coluna do DataFrame merged_df. A variável nan_proportion contém essas proporções, fornecendo uma medida da incompletude dos dados em cada coluna.

# %%
CO_AQI_Category_encoded = pd.get_dummies(merged_df['CO AQI Category'], prefix='CO AQI category')
#merged_df.drop('Ozone AQI Category',axis=1)
merged_df = pd.concat([merged_df,CO_AQI_Category_encoded ],axis=1)

# %%
Ozone_AQI_Category_encoded = pd.get_dummies(merged_df['Ozone AQI Category'], prefix='Ozone AQI category')
#merged_df.drop('Ozone AQI Category',axis=1)
merged_df = pd.concat([merged_df,Ozone_AQI_Category_encoded],axis=1)

# %%
NO2_AQI_Category_encoded = pd.get_dummies(merged_df['NO2 AQI Category'], prefix='NO2 AQI category')
#merged_df.drop('NO2 AQI Category',axis=1)
merged_df = pd.concat([merged_df, NO2_AQI_Category_encoded],axis=1)

# %%
PM25_AQI_Category_encoded = pd.get_dummies(merged_df['PM2.5 AQI Category'], prefix='PM2.5 AQI category')
#merged_df.drop('NO2 AQI Category',axis=1)
merged_df = pd.concat([merged_df, PM25_AQI_Category_encoded],axis=1)

# %% [markdown]
# O código apresentado realiza a codificação das variáveis categóricas 'CO AQI Category', 'Ozone AQI Category', 'NO2 AQI Category' e 'PM2.5 AQI Category' utilizando a função pd.get_dummies(). Essa codificação transforma cada categoria em uma nova coluna binária, com o prefixo correspondente ao nome da categoria. Em seguida, o DataFrame original merged_df é concatenado com as colunas codificadas usando pd.concat()

# %%
merged_df
# Out:
#            Country            City  AQI Value                    AQI Category
# 1      Afghanistan        Kuhestan        151                       Unhealthy  \
# 2      Afghanistan          Qunduz        117  Unhealthy for Sensitive Groups
# 3      Afghanistan          Rostaq        113  Unhealthy for Sensitive Groups
# 4      Afghanistan          Tokzar         77                        Moderate
# 5      Afghanistan         Carikar         67                        Moderate
# ...            ...             ...        ...                             ...
# 18571     Zimbabwe      Zvishavane         39                            Good
# 18572     Zimbabwe    Mount Darwin         26                            Good
# 18573     Zimbabwe        Bulawayo         65                        Moderate
# 18574     Zimbabwe      Beitbridge         52                        Moderate
# 18575     Zimbabwe  Victoria Falls         26                            Good
#
# ...

# %%
merged_df.dtypes
# Out:
# Country                                               object
# City                                                  object
# AQI Value                                              int64
# AQI Category                                          object
# CO AQI Value                                           int64
# CO AQI Category                                       object
# Ozone AQI Value                                        int64
# Ozone AQI Category                                    object
# NO2 AQI Value                                          int64
# NO2 AQI Category                                      object
# PM2.5 AQI Value                                        int64
# PM2.5 AQI Category                                    object
# PIB_2018                                             float64
# CO AQI category_Good                                    bool
# CO AQI category_Moderate                                bool
# ...

# %% [markdown]
# O DataFrame merged_df combina colunas com diferentes tipos de dados. Ele inclui informações categóricas, como 'Country', 'City' e categorias AQI (Qualidade do Índice de Ar), e colunas numéricas, como 'AQI Value', 'CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value' e 'PM2.5 AQI Value'. A coluna 'PIB_2018' contém valores numéricos de ponto flutuante. Além disso, foram adicionadas colunas binárias codificadas para representar as categorias das variáveis categóricas.

# %%
from sklearn.preprocessing import LabelEncoder

# Definir a lista de colunas categóricas
col = ['AQI Category', 'CO AQI Category', 'Ozone AQI Category', 'NO2 AQI Category', 'PM2.5 AQI Category']

# Instanciar o objeto LabelEncoder
le = LabelEncoder()

# Iterar sobre as colunas e realizar a transformação
for column in col:
    if column in merged_df.columns:
        merged_df[column] = le.fit_transform(merged_df[column].astype(str))

# %% [markdown]
# O código utiliza o LabelEncoder do sklearn.preprocessing para codificar colunas categóricas em merged_df. As colunas a serem codificadas são especificadas na lista col. O LabelEncoder é instanciado e aplicado a cada coluna categórica no loop for. A transformação mapeia os valores únicos para valores numéricos correspondentes. As colunas categóricas em merged_df são substituídas pelos valores codificados.

# %%
merged_df.dtypes
# Out:
# Country                                               object
# City                                                  object
# AQI Value                                              int64
# AQI Category                                           int32
# CO AQI Value                                           int64
# CO AQI Category                                        int32
# Ozone AQI Value                                        int64
# Ozone AQI Category                                     int32
# NO2 AQI Value                                          int64
# NO2 AQI Category                                       int32
# PM2.5 AQI Value                                        int64
# PM2.5 AQI Category                                     int32
# PIB_2018                                             float64
# CO AQI category_Good                                    bool
# CO AQI category_Moderate                                bool
# ...

# %%
merged_df
# Out:
#            Country            City  AQI Value  AQI Category  CO AQI Value
# 1      Afghanistan        Kuhestan        151             3             1  \
# 2      Afghanistan          Qunduz        117             4             1
# 3      Afghanistan          Rostaq        113             4             1
# 4      Afghanistan          Tokzar         77             2             1
# 5      Afghanistan         Carikar         67             2             0
# ...            ...             ...        ...           ...           ...
# 18571     Zimbabwe      Zvishavane         39             0             1
# 18572     Zimbabwe    Mount Darwin         26             0             0
# 18573     Zimbabwe        Bulawayo         65             2             1
# 18574     Zimbabwe      Beitbridge         52             2             2
# 18575     Zimbabwe  Victoria Falls         26             0             0
#
#        CO AQI Category  Ozone AQI Value  Ozone AQI Category  NO2 AQI Value
# ...

# %%
merged_df.columns
# Out:
# Index(['Country', 'City', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category', 'PIB_2018', 'CO AQI category_Good',
#        'CO AQI category_Moderate', 'Ozone AQI category_Good',
#        'Ozone AQI category_Moderate', 'Ozone AQI category_Unhealthy',
#        'Ozone AQI category_Unhealthy for Sensitive Groups',
#        'Ozone AQI category_Very Unhealthy', 'NO2 AQI category_Good',
#        'NO2 AQI category_Moderate', 'PM2.5 AQI category_Good',
#        'PM2.5 AQI category_Hazardous', 'PM2.5 AQI category_Moderate',
#        'PM2.5 AQI category_Unhealthy',
#        'PM2.5 AQI category_Unhealthy for Sensitive Groups',
#        'PM2.5 AQI category_Very Unhealthy'],
#       dtype='object')

# %%
desc_stats =merged_df.describe()
print(desc_stats)
# Out:
#           AQI Value  AQI Category  CO AQI Value  CO AQI Category
# count  18523.000000  18523.000000  18523.000000     18523.000000  \
# mean      75.104465      1.433083      1.383793         0.000054
# std       60.559851      1.390805      1.669978         0.007348
# min        7.000000      0.000000      0.000000         0.000000
# 25%       39.000000      0.000000      1.000000         0.000000
# 50%       55.000000      2.000000      1.000000         0.000000
# 75%       85.000000      2.000000      1.000000         0.000000
# max      500.000000      5.000000     67.000000         1.000000
#
#        Ozone AQI Value  Ozone AQI Category  NO2 AQI Value  NO2 AQI Category
# count     18523.000000        18523.000000   18523.000000      18523.000000  \
# mean         36.708417            0.196512       2.355018          0.000702
# std          30.081764            0.618118       4.280164          0.026483
# ...

# %%
desc_stats = merged_df[['AQI Value', 'CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value', 'PIB_2018']].describe()
print(desc_stats)
# Out:
#           AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value
# count  18523.000000  18523.000000     18523.000000   18523.000000  \
# mean      75.104465      1.383793        36.708417       2.355018
# std       60.559851      1.669978        30.081764       4.280164
# min        7.000000      0.000000         0.000000       0.000000
# 25%       39.000000      1.000000        22.000000       0.000000
# 50%       55.000000      1.000000        31.000000       1.000000
# 75%       85.000000      1.000000        41.000000       3.000000
# max      500.000000     67.000000       210.000000      69.000000
#
#        PM2.5 AQI Value       PIB_2018
# count     18523.000000   18523.000000
# mean         71.223560   25521.875441
# std          59.089264   17132.943323
# min           0.000000     744.182072
# 25%          34.000000    8951.085654
# 50%          55.000000   19844.645670
# 75%          84.000000   41830.426330
# max         500.000000  126898.425900

# %% [markdown]
# Com base nos dados estatísticos fornecidos, podemos tirar as seguintes conclusões:
#
# Distribuição dos dados: As variáveis AQI Value, CO AQI Value, Ozone AQI Value, NO2 AQI Value e PM2.5 AQI Value têm uma ampla variação, conforme evidenciado pela diferença entre os valores mínimo e máximo. Isso indica que há uma diversidade de níveis de qualidade do ar registrados nas amostras.
#
# Média: A média do AQI Value é de aproximadamente 75.1, o que sugere uma média geral de qualidade do ar moderada.
#
# Desvio padrão: Os desvios padrão das variáveis são relativamente altos, indicando uma dispersão considerável em torno das médias. Isso sugere uma variabilidade substancial nos níveis de qualidade do ar e destaca a importância de analisar a distribuição dos dados além das medidas centrais.
#
# Primeiro Quartil (25%): O valor do primeiro quartil (Q1) para as variáveis AQI Value, CO AQI Value, Ozone AQI Value, NO2 AQI Value e PM2.5 AQI Value é igual a 39, 1, 22, 0 e 34, respectivamente. Isso significa que 25% dos dados para cada variável está abaixo desses valores.
#
# Segundo Quartil (50% ou Mediana): O valor do segundo quartil (Q2), que é também a mediana, para as variáveis AQI Value, CO AQI Value, Ozone AQI Value, NO2 AQI Value e PM2.5 AQI Value é igual a 55, 1, 31, 1 e 55, respectivamente. Isso indica que 50% dos dados está abaixo desses valores.
#
# Terceiro Quartil (75%): O valor do terceiro quartil (Q3) para as variáveis AQI Value, CO AQI Value, Ozone AQI Value, NO2 AQI Value e PM2.5 AQI Value é igual a 85, 1, 41, 3 e 84, respectivamente. Isso significa que 75% dos dados está abaixo desses valores.
#
# Esses quartis nos dão uma ideia da distribuição dos dados e nos ajudam a entender onde a maioria dos valores está localizada. Por exemplo, podemos observar que os valores mais baixos (25% dos dados) para AQI Value e PM2.5 AQI Value estão abaixo de 39 e 34, respectivamente. Além disso, os valores mais altos (75% dos dados) para AQI Value e PM2.5 AQI Value estão abaixo de 85 e 84, respectivamente
#
# Relação com o PIB: O valor mínimo do PIB_2018 é de 744.182072, enquanto o valor máximo é de 126898.425900. Isso indica uma grande variação nos níveis de Produto Interno Bruto entre os países analisados

# %%
num_bins = 10 

counts, bins, _ = plt.hist(merged_df['AQI Value'], bins=num_bins)
print(bins)
# Out:
# [  7.   56.3 105.6 154.9 204.2 253.5 302.8 352.1 401.4 450.7 500. ]

# %% [markdown]
# Com base nos intervalos gerados pelo histograma para a variável "AQI Value", podemos fazer as seguintes conclusões:
#
# Distribuição dos dados:
#
# Frequência de observações: Podemos inferir que a maioria das observações (frequência) está concentrada nos intervalos [7.0 - 56.3) e [56.3 - 105.6), uma vez que esses intervalos têm uma extensão menor em relação aos demais.
#
# Valores extremos: Os intervalos [450.7 - 500.0] e [7.0 - 56.3) correspondem aos valores extremos mais baixos e mais altos, respectivamente. Isso indica a presença de valores atípicos nessas faixas.

# %%
num_bins = 10 

counts, bins, _ = plt.hist(merged_df['CO AQI Value'], bins=num_bins)
print(bins)
# Out:
# [ 0.   6.7 13.4 20.1 26.8 33.5 40.2 46.9 53.6 60.3 67. ]

# %% [markdown]
# De acordo com as histograma da coluna 'CO AQI Value', podemos tirar as seguintes informações:
#
# O intervalo de valores do CO AQI Value varia de 0 a 67.
# A maior concentração de dados está nos bins entre 0 e 13.4, indicando que a maioria dos valores do CO AQI Value está nessa faixa.
# À medida que os bins avançam, de 13.4 a 67, há uma diminuição gradual na frequência dos valores do CO AQI Value, indicando que valores mais altos são menos comuns.
# Essas conclusões sugerem que a maioria dos dados de CO AQI Value está em níveis mais baixos, o que pode indicar que a concentração de monóxido de carbono na maioria das observações é relativamente baixa. No entanto, ainda existem algumas observações com níveis mais elevados de CO AQI Value, embora sejam menos frequentes.

# %%
num_bins = 10 

counts, bins, _ = plt.hist(merged_df['Ozone AQI Value'], bins=num_bins)
print(bins)
# Out:
# [  0.  21.  42.  63.  84. 105. 126. 147. 168. 189. 210.]

# %% [markdown]
# Essas conclusões sugerem que a maioria dos dados de Ozone AQI Value está em níveis mais baixos, o que pode indicar que a concentração de ozônio na maioria das observações é relativamente baixa. No entanto, ainda existem algumas observações com níveis mais elevados de Ozone AQI Value, embora sejam menos frequentes.

# %%
num_bins = 10 

counts, bins, _ = plt.hist(merged_df['NO2 AQI Value'], bins=num_bins)
print(bins)
# Out:
# [ 0.   6.9 13.8 20.7 27.6 34.5 41.4 48.3 55.2 62.1 69. ]

# %% [markdown]
# De acordo com a análise do histograma para a coluna 'NO2 AQI Value' indicam que a maioria dos valores está concentrada na faixa de 0 a 13.8. Conforme os valores aumentam, a frequência diminui gradualmente, sugerindo que níveis mais altos de NO2 AQI Value são menos comuns nos dados analisados. Isso pode indicar que a concentração de dióxido de nitrogênio na maioria das observações é relativamente baixa, com algumas exceções de valores mais elevados.

# %%
num_bins = 10 

counts, bins, _ = plt.hist(merged_df['PM2.5 AQI Value'], bins=num_bins)
print(bins)
# Out:
# [  0.  50. 100. 150. 200. 250. 300. 350. 400. 450. 500.]

# %% [markdown]
# De acordo com a análise para a coluna 'NO2 AQI Value' indicam que a maioria dos valores está concentrada na faixa de 0 a 13.8. Conforme os valores aumentam, a frequência diminui gradualmente, sugerindo que níveis mais altos de NO2 AQI Value são menos comuns nos dados analisados. Isso pode indicar que a concentração de dióxido de nitrogênio na maioria das observações é relativamente baixa, com algumas exceções de valores mais elevados.

# %%
num_bins = 10 

counts, bins, _ = plt.hist(merged_df['PIB_2018'], bins=num_bins)
print(bins)
# Out:
# [   744.182072   13359.6064548  25975.0308376  38590.4552204
#   51205.8796032  63821.303986   76436.7283688  89052.1527516
#  101667.5771344 114283.0015172 126898.4259   ]

# %% [markdown]
# Com a análise da coluna 'PIB_2018' indicam que a maioria dos valores está distribuída entre 744.18 e 13359.61. À medida que os valores aumentam, a frequência diminui gradualmente, indicando que os valores mais altos de PIB são menos comuns nos dados analisados. Isso sugere que a maioria dos países tem um PIB relativamente baixo, com poucos países apresentando valores significativamente mais altos.

# %%
corr_matrix = merged_df[['AQI Value', 'CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value', 'PIB_2018']].corr()
print(corr_matrix)
# Out:
#                  AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value
# AQI Value         1.000000      0.448968         0.413711       0.294493  \
# CO AQI Value      0.448968      1.000000         0.193762       0.626471
# Ozone AQI Value   0.413711      0.193762         1.000000      -0.118926
# NO2 AQI Value     0.294493      0.626471        -0.118926       1.000000
# PM2.5 AQI Value   0.985130      0.458008         0.353776       0.321170
# PIB_2018         -0.379403     -0.202159        -0.051685       0.002032
#
#                  PM2.5 AQI Value  PIB_2018
# AQI Value               0.985130 -0.379403
# CO AQI Value            0.458008 -0.202159
# Ozone AQI Value         0.353776 -0.051685
# NO2 AQI Value           0.321170  0.002032
# PM2.5 AQI Value         1.000000 -0.401985
# PIB_2018               -0.401985  1.000000

# %% [markdown]
# Com base na matriz de correlação apresentada, podemos tirar algumas conclusões:
#
# AQI Value e PM2.5 AQI Value estão altamente correlacionados (0.985130): Existe uma forte correlação positiva entre essas duas variáveis. Isso sugere que o AQI Value é fortemente influenciado pelos níveis de PM2.5 (material particulado com diâmetro igual ou inferior a 2,5 micrômetros) na atmosfera.
#
# AQI Value e CO AQI Value estão moderadamente correlacionados (0.448968): Há uma correlação positiva moderada entre o AQI Value e o CO AQI Value. Isso indica que a qualidade do ar medida pelo AQI Value pode ser afetada pelos níveis de monóxido de carbono (CO) na atmosfera.
#
# AQI Value e Ozone AQI Value estão moderadamente correlacionados (0.413711): Existe uma correlação positiva moderada entre o AQI Value e o Ozone AQI Value. Isso sugere que a qualidade do ar medida pelo AQI Value pode ser influenciada pelos níveis de ozônio na atmosfera.
#
# AQI Value e NO2 AQI Value têm uma correlação fraca (0.294493): Existe uma correlação positiva fraca entre o AQI Value e o NO2 AQI Value. Isso indica que a qualidade do ar medida pelo AQI Value pode ter uma relação limitada com os níveis de dióxido de nitrogênio (NO2) na atmosfera.
#
# PIB_2018 e AQI Value têm uma correlação negativa moderada (-0.379403): Existe uma correlação negativa moderada entre o PIB_2018 e o AQI Value. Isso sugere que países ou regiões com maior Produto Interno Bruto (PIB) tendem a ter uma melhor qualidade do ar, pelo menos no ano de 2018.

# %%
columns_to_plot1 = ['Country','PIB_2018','AQI Category', 'CO AQI Value']

# %%
import seaborn as sns

# %%
sns.pairplot(merged_df[columns_to_plot1],hue='PIB_2018')

# %%
import matplotlib.pyplot as plt

plt.hist(merged_df['AQI Value'])
# Out:
# (array([9557., 5325., 1489., 1744.,  173.,   53.,   32.,   24.,   15.,
#          111.]),
#  array([  7. ,  56.3, 105.6, 154.9, 204.2, 253.5, 302.8, 352.1, 401.4,
#         450.7, 500. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# O histograma mostra a distribuição dos valores da variável 'AQI Value' em diferentes intervalos. Ao analisar o histograma, podemos perceber que a maior parte dos valores se concentra nos primeiros intervalos, o que indica uma frequência maior de valores baixos de AQI. Isso sugere que a maioria das observações apresenta uma boa qualidade do ar, com níveis mais baixos de poluição.

# %%
merged_df.columns
# Out:
# Index(['Country', 'City', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category', 'PIB_2018', 'CO AQI category_Good',
#        'CO AQI category_Moderate', 'Ozone AQI category_Good',
#        'Ozone AQI category_Moderate', 'Ozone AQI category_Unhealthy',
#        'Ozone AQI category_Unhealthy for Sensitive Groups',
#        'Ozone AQI category_Very Unhealthy', 'NO2 AQI category_Good',
#        'NO2 AQI category_Moderate', 'PM2.5 AQI category_Good',
#        'PM2.5 AQI category_Hazardous', 'PM2.5 AQI category_Moderate',
#        'PM2.5 AQI category_Unhealthy',
#        'PM2.5 AQI category_Unhealthy for Sensitive Groups',
#        'PM2.5 AQI category_Very Unhealthy'],
#       dtype='object')

# %%
merged_df
# Out:
#            Country            City  AQI Value  AQI Category  CO AQI Value
# 1      Afghanistan        Kuhestan        151             3             1  \
# 2      Afghanistan          Qunduz        117             4             1
# 3      Afghanistan          Rostaq        113             4             1
# 4      Afghanistan          Tokzar         77             2             1
# 5      Afghanistan         Carikar         67             2             0
# ...            ...             ...        ...           ...           ...
# 18571     Zimbabwe      Zvishavane         39             0             1
# 18572     Zimbabwe    Mount Darwin         26             0             0
# 18573     Zimbabwe        Bulawayo         65             2             1
# 18574     Zimbabwe      Beitbridge         52             2             2
# 18575     Zimbabwe  Victoria Falls         26             0             0
#
#        CO AQI Category  Ozone AQI Value  Ozone AQI Category  NO2 AQI Value
# ...

# %%
merged_df.describe
# Out:
# <bound method NDFrame.describe of            Country            City  AQI Value  AQI Category  CO AQI Value
# 1      Afghanistan        Kuhestan        151             3             1  \
# 2      Afghanistan          Qunduz        117             4             1
# 3      Afghanistan          Rostaq        113             4             1
# 4      Afghanistan          Tokzar         77             2             1
# 5      Afghanistan         Carikar         67             2             0
# ...            ...             ...        ...           ...           ...
# 18571     Zimbabwe      Zvishavane         39             0             1
# 18572     Zimbabwe    Mount Darwin         26             0             0
# 18573     Zimbabwe        Bulawayo         65             2             1
# 18574     Zimbabwe      Beitbridge         52             2             2
# 18575     Zimbabwe  Victoria Falls         26             0             0
#
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
import seaborn as sns
import pandas as pd
import numpy as np

# %%
X = merged_df.drop('PIB_2018', axis=1).select_dtypes(include=np.number)
y = merged_df['PIB_2018']

# %%
clfs = [
    DecisionTreeRegressor(),
    RandomForestRegressor(),
    RandomForestRegressor(max_depth=8),
    RandomForestRegressor(max_depth=10),
    SVR(),
    KNeighborsRegressor()
]

# %%
from sklearn.model_selection import cross_val_score

classifiers = []
scores = []

for clf in clfs:
    cv_scores = cross_val_score(clf, X, y, cv=10, scoring='neg_mean_squared_log_error')
    for s in cv_scores:
        classifiers.append(str(clf))
        scores.append(float(s))

# %%
results = pd.DataFrame({'classifier': classifiers, 'Neg Mean Squared Log Error': scores})

# %%
results
# Out:
#                              classifier  Neg Mean Squared Log Error
# 0               DecisionTreeRegressor()                   -0.647894
# 1               DecisionTreeRegressor()                   -0.633652
# 2               DecisionTreeRegressor()                   -0.354803
# 3               DecisionTreeRegressor()                   -0.599630
# 4               DecisionTreeRegressor()                   -0.459160
# 5               DecisionTreeRegressor()                   -0.413501
# 6               DecisionTreeRegressor()                   -0.650629
# 7               DecisionTreeRegressor()                   -0.808323
# 8               DecisionTreeRegressor()                   -0.419883
# 9               DecisionTreeRegressor()                   -0.955139
# 10              RandomForestRegressor()                   -0.507422
# 11              RandomForestRegressor()                   -0.334431
# 12              RandomForestRegressor()                   -0.181431
# ...

# %% [markdown]
# DecisionTreeRegressor:
# Média do Erro Quadrático Médio Logarítmico Negativo: -0,535579
#
# RandomForestRegressor:
# Média do Erro Quadrático Médio Logarítmico Negativo: -0,332297
# Média do Erro Quadrático Médio Logarítmico Negativo com max_depth=8: -0,305342
# Média do Erro Quadrático Médio Logarítmico Negativo com max_depth=10: -0,329754
#
# SVR:
# Média do Erro Quadrático Médio Logarítmico Negativo: -0,785271
# KNeighborsRegressor:
#
# Média do Erro Quadrático Médio Logarítmico Negativo: -0,408096
#
# Em conclusão, o RandomForestRegressor,  com uma profundidade máxima (max_depth) maior, apresenta o melhor desempenho com o menor erro quadrático médio logarítmico negativo. Por outro lado, o DecisionTreeRegressor mostra o pior desempenho. SVR e KNeighborsRegressor ficam intermediários. Para tarefas de regressão nessa caso, é recomendado usar o RandomForestRegressor com uma profundidade máxima adequada para obter melhores resultados.

# %%
sns.set(rc={'figure.figsize': (25, 8)})
sns.violinplot(data=results, x='classifier', y='Neg Mean Squared Log Error')
# Out:
# <Axes: xlabel='classifier', ylabel='Neg Mean Squared Log Error'>

# %% [markdown]
# Os classificadores que apresentaram os menores valores negativos têm melhor desempenho em relação a essa métrica.
#
# Portanto, com base nos valores fornecidos e o gráfico acima, os classificadores com os menores valores de "Neg Mean Squared Log Error" são:
#
# Random Forest Regressor com max_depth=8: -0.130004
# Random Forest Regressor com max_depth=10: -0.133313
# Random Forest Regressor: -0.179901
# Esses classificadores apresentam os melhores desempenhos em relação à métrica "Neg Mean Squared Log Error" entre os listados

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Definir os parâmetros para a busca em grid
param_grid = {
    'max_depth': [2, 5, 8],
    'n_estimators': [100, 300, 500],
    'criterion': ['friedman_mse', 'poisson']
}

# Criar o modelo RandomForestRegressor
model = RandomForestRegressor()

# Realizar a busca em grid com parâmetros otimizados para resposta mais rápida
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_squared_log_error', cv=5, n_jobs=-1)
grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'poisson'],
#                          'max_depth': [2, 5, 8],
#                          'n_estimators': [100, 300, 500]},
#              scoring='neg_mean_squared_log_error')

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'poisson', 'max_depth': 8, 'n_estimators': 100}
